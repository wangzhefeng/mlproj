# %%
import config
import data_logging

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.数据读取

# %%
link_info = pd.read_csv(
    os.path.join(config.data_dir, "gy_contest_link_info.txt"), 
    delimiter = ";", 
    dtype = {"link_ID": object}
)
link_top = pd.read_csv(
    os.path.join(config.data_dir, "gy_contest_link_top.txt"), 
    delimiter = ";", 
    dtype = {"link_ID": object}
)
df = pd.read_csv(
    os.path.join(config.data_dir, "quaterfinal_gy_cmp_training_traveltime.txt"),
    delimiter = ";", 
    dtype = {"link_ID": object}
)

# %%
data_logging.data_logging(data = link_info, data_name = "link_info")
# Out:
# ====================
# link_info.head()
# ====================
#                link_ID  length  width  link_class
# 0  4377906289869500514      57      3           1
# 1  4377906284594800514     247      9           1
# 2  4377906289425800514     194      3           1
# 3  4377906284525800514     839      3           1
# 4  4377906284422600514      55     12           1
# ====================
# link_info.tail()
# ====================
#                  link_ID  length  width  link_class
# 127  4377906288421600514     128      9           1
# 128  4377906289041600514     208      9           1
# 129  4377906286032600514     257     12           1
# 130  4377906281234600514      16      3           1
# 131  4377906286334600514      33     15           1
# ====================
# link_info.info()
# ====================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link_ID     132 non-null    object
#  1   length      132 non-null    int64
#  2   width       132 non-null    int64
#  3   link_class  132 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 4.2+ KB
# None

# %%
data_logging.data_logging(data = link_info, data_name = "link_top")
# Out:
# ====================
# link_top.head()
# ====================
#                link_ID  length  width  link_class
# 0  4377906289869500514      57      3           1
# 1  4377906284594800514     247      9           1
# 2  4377906289425800514     194      3           1
# 3  4377906284525800514     839      3           1
# 4  4377906284422600514      55     12           1
# ====================
# link_top.tail()
# ====================
#                  link_ID  length  width  link_class
# 127  4377906288421600514     128      9           1
# 128  4377906289041600514     208      9           1
# 129  4377906286032600514     257     12           1
# 130  4377906281234600514      16      3           1
# 131  4377906286334600514      33     15           1
# ====================
# link_top.info()
# ====================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   link_ID     132 non-null    object
#  1   length      132 non-null    int64
#  2   width       132 non-null    int64
#  3   link_class  132 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 4.2+ KB
# None

# %%
data_logging.data_logging(data = df, data_name = "df")
# Out:
# ====================
# df.head()
# ====================
#                link_ID        date                              time_interval  \
# 0  4377906283422600514  2017-05-06  [2017-05-06 11:04:00,2017-05-06 11:06:00)
# 1  3377906289434510514  2017-05-06  [2017-05-06 10:42:00,2017-05-06 10:44:00)
# 2  3377906285934510514  2017-05-06  [2017-05-06 11:56:00,2017-05-06 11:58:00)
# 3  3377906285934510514  2017-05-06  [2017-05-06 17:46:00,2017-05-06 17:48:00)
# 4  3377906287934510514  2017-05-06  [2017-05-06 10:52:00,2017-05-06 10:54:00)
#
#    travel_time
# 0     1.386294
# 1     0.693147
# 2     3.589059
# 3     3.303217
# 4     2.433613
# ====================
# df.tail()
# ====================
#                       link_ID        date  \
# 10632039  4377906287663800514  2017-07-31
# 10632040  4377906288663800514  2017-07-31
# 10632041  4377906288663800514  2017-07-31
# 10632042  4377906288663800514  2017-07-31
# 10632043  3377906289044510514  2017-07-31
#
#                                       time_interval  travel_time
# 10632039  [2017-07-31 14:16:00,2017-07-31 14:18:00)     4.355426
# 10632040  [2017-07-31 07:08:00,2017-07-31 07:10:00)     1.481605
# 10632041  [2017-07-31 17:12:00,2017-07-31 17:14:00)     1.808289
# 10632042  [2017-07-31 17:38:00,2017-07-31 17:40:00)     3.627004
# 10632043  [2017-07-31 17:08:00,2017-07-31 17:10:00)     2.484907
# ====================
# df.info()
# ====================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10632044 entries, 0 to 10632043
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   link_ID        object
#  1   date           object
#  2   time_interval  object
#  3   travel_time    float64
# dtypes: float64(1), object(3)
# memory usage: 324.5+ MB
# None

# %% [markdown]
# ## 2.探索性数据分析(EDA)

# %% [markdown]
# # 3.特征工程

# %%
# 特征变换
df["travel_time"] = np.log1p(df["travel_time"])

# %%
# 数据平滑
def quantile_clip(group):
#     group.plot()
    group[group < group.quantile(0.05)] = group.quantile(0.05)
    group[group > group.quantile(0.95)] = group.quantile(0.95)
#     group.plot()
#     plt.show()
    return group
df["travel_time"] = df.groupby(["link_ID", "date"])["travel_time"].transform(quantile_clip)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-9dddf2811943> in <module>
#       7 #     plt.show()
#       8     return group
# ----> 9 df["travel_time"] = df.groupby(["link_ID", "date"])["travel_time"].transform(quantile_clip)
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/groupby/generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     505
#     506         if not isinstance(func, str):
# --> 507             return self._transform_general(func, *args, **kwargs)
#     508
#     509         elif func not in base.transform_kernel_allowlist:
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/groupby/generic.py in _transform_general(self, func, *args, **kwargs)
#     530         for name, group in self:
#     531             object.__setattr__(group, "name", name)
# --> 532             res = func(group, *args, **kwargs)
#     533
#     534             if isinstance(res, (DataFrame, Series)):
#
# <ipython-input-18-9dddf2811943> in quantile_clip(group)
#       2 def quantile_clip(group):
#       3 #     group.plot()
# ----> 4     group[group < group.quantile(0.05)] = group.quantile(0.05)
#       5     group[group > group.quantile(0.95)] = group.quantile(0.95)
#       6 #     group.plot()
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/arraylike.py in __lt__(self, other)
#      35     @unpack_zerodim_and_defer("__lt__")
#      36     def __lt__(self, other):
# ---> 37         return self._cmp_method(other, operator.lt)
#      38
#      39     @unpack_zerodim_and_defer("__le__")
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    4978         res_values = ops.comparison_op(lvalues, rvalues, op)
#    4979
# -> 4980         return self._construct_result(res_values, name=res_name)
#    4981
#    4982     def _logical_method(self, other, op):
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/series.py in _construct_result(self, result, name)
#    2761         # We do not pass dtype to ensure that the Series constructor
#    2762         #  does inference in the case where `result` has object-dtype.
# -> 2763         out = self._constructor(result, index=self.index)
#    2764         out = out.__finalize__(self)
#    2765
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     364                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     365
# --> 366                 data = SingleBlockManager.from_array(data, index)
#     367
#     368         generic.NDFrame.__init__(self, data)
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1581         """
#    1582         block = make_block(array, placement=slice(0, len(index)), ndim=1)
# -> 1583         return cls(block, index)
#    1584
#    1585     def _post_setstate(self):
#
# ~/.pyenv/versions/3.7.10/envs/ml/lib/python3.7/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1543     is_single_block = True
#    1544
# -> 1545     def __init__(
#    1546         self,
#    1547         block: Block,
#
# KeyboardInterrupt:

# %%
# 缺失值补全
date_range = pd.date_range("2016-07-01 00:00:00", "2016-07-31 00:00:00", freq = "2min") \
    .append(pd.date_range("2017-04-01 00:00:00", "2016-07-31 00:00:00", freq = "2min"))
new_index = pd.MultiIndex.from_product(
    [link_df["link_ID"].unique(), date_range], 
    names = ["link_ID", "time_interval_begin"]
)
df1 = pd.DateFrame(index = new_index).reset_index()
df3 = pd.merge(df1, df, on = ["link_ID", "time_interval_begin"], how = "left")
